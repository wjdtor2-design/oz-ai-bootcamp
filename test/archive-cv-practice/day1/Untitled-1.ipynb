# %%
from ultralytics import YOLO

model = YOLO("yolov8n.pt")

model.train(
    data="/Users/admin/yolo_dataset/data.yaml",
    epochs=50,
    imgsz=640,
    batch=4
)
# Out:
# Ultralytics 8.3.251 🚀 Python-3.10.19 torch-2.9.1 CPU (Apple M1 Pro)
# ...
